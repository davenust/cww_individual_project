# %%
import pandas as pd
# Create the years and durations lists
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

# Create a dictionary with the two lists
movie_dict = pd.DataFrame({
    'years': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
    'durations': [103, 101, 99, 100, 100, 95, 95, 96, 93, 90],
},
columns=['years', 'durations'])

# Print the dictionary
movie_dict
# Out:
#    years  durations
# 0   2011        103
# 1   2012        101
# 2   2013         99
# 3   2014        100
# 4   2015        100
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %%
# Import pandas under its usual alias
import pandas as pd

# Create a DataFrame from the dictionary
durations_df = pd.DataFrame(movie_dict)

# Print the DataFrame
durations_df
# Out:
#    years  durations
# 0   2011        103
# 1   2012        101
# 2   2013         99
# 3   2014        100
# 4   2015        100
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %%
# Import matplotlib.pyplot under its usual alias and create a figure
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,8))

# Draw a line plot of release_years and durations
plt.plot(years, durations, color='green', marker='o')

# Create a title
plt.title('Netflix Movie Durations 2011-2020')

# Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
# Read in the CSV as a DataFrame
netflix_df = pd.read_csv('netflix_data.csv')

# Print the first five rows of the DataFrame
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_df['genre'].value_counts().head(10)
# Out:
# Dramas              1384
# Comedies            1074
# Documentaries        751
# Action               721
# International TV     690
# Children             502
# Crime TV             369
# Kids                 359
# Stand-Up             354
# Horror Movies        244
# Name: genre, dtype: int64

# %%
# Subset the DataFrame for type "Movie"
netflix_df_movies_only = netflix_df[(netflix_df['type'] == 'Movie')]

# Select only the columns of interest
netflix_movies_col_subset = netflix_df_movies_only[['title', 'country', 'genre', 'release_year', 'duration']]

# Print the first five rows of the new DataFrame
netflix_movies_col_subset.to_csv('netflix_movies_col_subset', index=False)
netflix_movies_col_subset.head()
# Out:
#    title        country          genre  release_year  duration
# 1   7:19         Mexico         Dramas          2016        93
# 2  23:59      Singapore  Horror Movies          2011        78
# 3      9  United States         Action          2009        80
# 4     21  United States         Dramas          2008       123
# 6    122          Egypt  Horror Movies          2019        95

# %%
import matplotlib.pyplot as plt
# Create a figure and increase the figure size
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus year
plt.scatter(netflix_movies_col_subset['release_year'], netflix_movies_col_subset['duration'],color='blue', marker='o')

# Create a title
plt.title('Duration vs Year')

# Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Filter for durations shorter than 60 minutes
short_movies = netflix_movies_col_subset[netflix_movies_col_subset['duration'] < 60]

# Print the first 20 rows of short_movies
short_movies
# Out:
#                                                   title        country  \
# 35                                            #Rucker50  United States
# 55                  100 Things to do Before High School  United States
# 67    13TH: A Conversation with Oprah Winfrey & Ava ...            NaN
# 101                                   3 Seconds Divorce         Canada
# 146                                      A 3 Minute Hug         Mexico
# ...                                                 ...            ...
# 7679                    WWII: Report from the Aleutians  United States
# 7692  Ya no estoy aquí: Una conversación entre Guill...            NaN
# 7718                     Yoo Byung Jae: Discomfort Zone    South Korea
# 7771                                               Zion  United States
# 7784                                  Zulu Man in Japan            NaN
#
#               genre  release_year  duration
# 35    Documentaries          2016        56
# ...

# %%
# Define an empty list
colors=[]

# Iterate over rows of netflix_movies_col_subset
for row, ser in netflix_movies_col_subset.iterrows():
    if ser['genre'] == 'Children':
        colors.append('red')
    elif ser['genre'] == 'Documentaries' :
        colors.append('blue')
    elif ser['genre'] == "Stand-Up" :
        colors.append('green')
    else:
        colors.append('black')
        
# Inspect the first 10 values in your list using the slicing operator       
print(colors[:10])
# Out:
# ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'blue']

# %%
# Displaying the list of first 10 values using the slicing operator above, to list the Genre of movies 
netflix_movies_col_subset['genre'].head(10)
# Out:
# 1            Dramas
# 2     Horror Movies
# 3            Action
# 4            Dramas
# 6     Horror Movies
# 7            Dramas
# 8     Horror Movies
# 9     Horror Movies
# 10           Dramas
# 13    Documentaries
# Name: genre, dtype: object

# %%
# Set the figure style and initalize a new figure
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus release_year
plt.scatter(netflix_movies_col_subset['release_year'], netflix_movies_col_subset['duration'], color=colors, marker='o')


# Create a title and axis labels
plt.title("Movie duration by year of release")
plt.xlabel("Release year")
plt.ylabel("Duration (min)")

# Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Are we certain that movies are getting shorter?
highest_year = short_movies[['genre','release_year']]
print(highest_year.value_counts(ascending=False).head())

are_movies_getting_shorter ='We are having much of movies going above 60 mins each year, which shows that there is an increase in demand. Making them increase the duration time to satisfy the demand of the people'
print(are_movies_getting_shorter)
# Out:
# genre          release_year
# Documentaries  2017            35
# Children       2020            32
# Documentaries  2018            23
#                2016            22
# Children       2019            21
# dtype: int64
# We are having much of movies going above 60 mins each year, which shows that there is an increase in demand. Making them increase the duration time to satisfy the demand of the people
